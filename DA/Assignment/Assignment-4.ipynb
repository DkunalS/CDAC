# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# 1. Write a Python program to draw a line with suitable label in the x axis, yaxis and a title.
x = np.arange(1,51)
y = np.linspace(1,161,50)

plt.plot(x,y)
plt.xlabel("X- Axis")
plt.ylabel("Y- Axix")
plt.title("Draw a Line")
plt.show()

# %%
# 2. Write a Python program to draw a line using given axis values with suitablelabel in the x axis , y axis and a title.
x = [1,2,3]
y = [2,4,0]
plt.plot(x,y)
plt.xlim(1,3)
plt.ylim(0,4)
plt.xlabel("X- Axis")
plt.ylabel("Y- Axix")
plt.title("Draw a Line")
plt.show()

# %%
# 3. Write a Python program to draw a line using given axis values taken from atext file, with suitable label in the x axis, y axis and a title.
# Test Data:
#    test.txt
#     1   2
#     2   4
#     3   1

x = [1,2,3]
y = [2,4,0]
plt.plot(x,y)
plt.xlim(1,3)
plt.ylim(0,4)
plt.xlabel("X- Axis")
plt.ylabel("Y- Axix")
plt.title("Draw a Line")
plt.show()

# %%
#4. Write a Python program to draw line charts of the financial data of Alphabet Inc. between October 3, 2016 to October 7, 2016.
#    Sample Financial data (fdata.csv):
#            Date,       Open,         High,          Low,           Close
#            10-03-16,   774.25,       776.065002,    769.5,         772.559998
#            10-04-16,   776.030029,   778.710022,    772.890015,    776.429993
#            10-05-16,   779.309998,   782.070007,    775.650024,    776.469971
#            10-06-16,   779,          780.47998,     775.539978,    776.859985
#            10-07-16,   779.659973,   779.659973,    770.75,        775.080017

df = pd.read_csv('fdata.csv')
sns.lineplot(x='Date',y='Open',data=df,label='Open', color='blue')
sns.lineplot(x='Date',y='High',data=df,label='High', color='yellow')
sns.lineplot(x='Date',y='Low',data=df,label='Low', color='green')
sns.lineplot(x='Date',y='Close',data=df,label='Close', color='red')

plt.show()

# %%
# 5. Write a Python program to plot two or more lines on same plot with suitablelegends of each line.


data = {
    'X': [10, 20, 30, 10, 20, 30],
    'Y': [20,40,10, 40, 10, 30],
    'Line': ['Line 1', 'Line 1', 'Line 1', 'Line 2', 'Line 2', 'Line 2']
}

sns.lineplot(data=data, x='X', y='Y', hue='Line')
plt.xlim(10,30)
plt.ylim(10,40)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Two or more lines on same plot with suitable legends")

plt.tight_layout()
plt.show()

# %%
# 6. Write a Python program to plot two or more lines with legends, different widths and colors.
x1 = [10, 20, 30]
y1 = [20, 40, 10]

x2 = [10, 20, 30]
y2 = [40, 10, 30]

plt.plot(x1, y1, label='Line 1-width-3', linewidth=3,color = 'blue')
plt.plot(x2, y2, label='Line 2-width-5', linewidth=5,color = 'red')

plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.xticks([10, 20, 30])
plt.xlim(10, 30)
plt.ylim(10, 40)
plt.title("two or more lines with legends, different widths and colors with sutiable legends")
plt.legend()

plt.tight_layout()
plt.show()

# %%
# 7. Write a Python program to plot two or more lines with different styles.
x1 = [10, 20, 30]
y1 = [20, 40, 10]

x2 = [10, 20, 30]
y2 = [40, 10, 30]

plt.plot(x1, y1, label='Line 1-dotted', linewidth=3,color = 'blue', linestyle='dotted')
plt.plot(x2, y2, label='Line 2-dashed', linewidth=5,color = 'red',linestyle='dashed')

plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.xticks([10, 20, 30])
plt.xlim(10, 30)
plt.ylim(10, 40)
plt.title("two or more lines with legends, different widths and colors with sutiable legends")
plt.legend()

plt.tight_layout()
plt.show()

# %%
# 8. Write a Python program to plot two or more lines and set the line markers
x1 = [1,4,5,6,7]
y1 = [2,6,3,6,3]


plt.plot(x1, y1, label='Line 1',color = 'red',marker = 'o', linestyle='dotted',markerfacecolor='blue', markeredgecolor='black')

plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.xlim(1,8)
plt.ylim(1,8)
plt.title("Display Markers")

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Pending**

# %%
# 9. Write a Python program to display the current axis limits values and set new axis values.
x1 = [0,40]
y1 = [0,150]
plt.axis([0,100,0,200])
plt.plot(x1,y1)
plt.title("Draw a line")
plt.show()

# %%
# 10. Write a Python program to plot quantities which have an x and y position.
a1 = [2,3,5,6,8]
b1 = [1,5,10,18,20]

a2 = [3,4,6,7,9]
b2 = [2,6,11,20,22]

plt.figure(figsize=(6,5))
plt.scatter(a1, b1, color = 'blue',marker='*')
plt.scatter(a2, b2, color = 'red')
plt.axis([0,10,0,30])
plt.show()

# %%
# 11. Write a Python program to plot several lines with different format styles inone command using arrays.
x_axis = np.arange(0,5,0.2)
y_axis1 = x_axis * 1.2
y_axis2 = x_axis ** 2
y_axis3 = x_axis ** 3

plt.figure(figsize=(6,5))
plt.scatter(x_axis, y_axis1, color = 'green',marker='_')
plt.scatter(x_axis, y_axis2, color = 'blue',marker='s')
plt.scatter(x_axis, y_axis3, color = 'red', marker='^')
plt.axis([0,5,0,120])
# Out:
# (0.0, 5.0, 0.0, 120.0)

# %%
# 12. Write a Python program to create multiple types of charts (a simple curveand plot some quantities) on a single set of axes.
x_axis = ['2016-10-03', '2016-10-04', '2016-10-05', '2016-10-06', '2016-10-07']
y_axis = [772.5,776.5,776.5,776.7, 775]

plt.figure(figsize=(6,5))
plt.plot(x_axis, y_axis, color = 'red', marker='o')
plt.yticks(np.arange(772.5, 777.5, 0.5))
plt.show()

# %%
# 13. Write a Python program to display the grid and draw line charts of the closing value of Alphabet Inc. between October 3, 2016 to October 7, 2016.
# Customized the grid lines with linestyle -, width .5. and color blue.
#            Date,        Close
#            03-10-16,    772.559998
#            04-10-16,    776.429993
#            05-10-16,    776.469971
#            06-10-16,    776.859985
#            07-10-16,    775.080017


data = {'Date' : ['2016-10-03', '2016-10-04', '2016-10-05', '2016-10-06', '2016-10-07'],
       'Close' : [772.559998, 776.429993, 776.469971, 776.859985, 775.080017]}

df = pd.DataFrame(data)
plt.figure(figsize=(6,5))
plt.title("Closing stock value of Alphabet inc.")
plt.xlabel('Date')
plt.ylabel('Closing Value')
plt.plot(df['Date'], df['Close'], color = 'red', marker='o')
plt.grid()
plt.xlim('2016-10-03','2016-10-07')
plt.ylim(772.5,777.0)
plt.yticks(np.arange(772.5, 777.5, 0.5))
plt.show()

# %%
# 14. Write a Python program to display the grid and draw line charts of the closing value of Alphabet Inc. between October 3, 2016 to October 7, 2016.
# Customized the grid lines with rendering with a larger grid (major grid) and asmaller grid (minor grid).Turn on the grid but turn off ticks.

df = pd.DataFrame(data)
plt.figure(figsize=(6,5))
plt.title("Closing stock value of Alphabet inc.")
plt.xlabel('Date')
plt.ylabel('Closing Value')
plt.plot(df['Date'], df['Close'], color = 'red', marker='p')
plt.grid(which='major', color='red', linestyle='-', linewidth=0.7)
plt.minorticks_on()
plt.xlim('2016-10-03','2016-10-07')
plt.ylim(772.5,777.0)
plt.grid(which='minor', color='grey', linestyle=':', linewidth=0.5)
plt.yticks(np.arange(772.5, 777.5, 0.5))
plt.show()

# %%
# 15. Write a Python program to create multiple plots.
fig, axs = plt.subplots(1, 1, figsize=(12, 4))
fig, axs1 = plt.subplots(1, 3, figsize=(12, 4))
plt.show()
