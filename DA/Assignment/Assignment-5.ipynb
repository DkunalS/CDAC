# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# 1. Write a Python programming to display a bar chart of the popularity of programming Languages.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

prmng_lang = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity= [22.2, 17.6, 8.8, 8, 7.7, 6.7]

plt.bar(prmng_lang, popularity, color='blue', zorder=3)
plt.title("Popularity of Programming Language Worldwide,\n Oct 2017 compared to a year ago")
plt.xlabel("Language")
plt.ylabel("Popularity")
plt.xlim(-.4,5.4)
plt.ylim(0,25)

plt.minorticks_on()
plt.grid(which='minor', color='grey', linewidth=0.3)
plt.grid(which='major', color='red', linewidth=0.5, alpha=0.5)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

plt.show()

# %%
# 2. Write a Python programming to display a horizontal bar chart of the popularity of programming Languages.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

prmng_lang = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity= [22.2, 17.6, 8.8, 8, 7.7, 6.7]

plt.barh(prmng_lang,popularity, color='green',zorder = 3)
plt.title("Popularity of Programming Language Worldwide,\n Oct 2017 compared to a year ago")
plt.xlabel("Popularity")
plt.ylabel("Language")
plt.ylim(-.4,5.4)
plt.xlim(0,25)
plt

plt.minorticks_on()
plt.grid(which='minor', color='grey', linewidth=0.3)
plt.grid(which='major', color='red', linewidth=0.5, alpha=0.5)

plt.show()

# %%
# 3. Write a Python programming to display a bar chart of the popularity of programming Languages. Use uniform color.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

prmng_lang = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

# Invert the popularity values to flip the bars upside down
inverted_popularity = [-p for p in popularity]

plt.bar(prmng_lang, inverted_popularity, color='blue', zorder=3)
plt.title("Popularity of Programming Language Worldwide,\n Oct 2017 compared to a year ago")
plt.xlabel("Language")
plt.ylabel("Popularity")

# Invert the y-axis to show negative values at the bottom
plt.xlim(-.4, 5.4)
plt.ylim(-25, 0)

plt.minorticks_on()
plt.grid(which='minor', color='grey', linewidth=0.3)
plt.grid(which='major', color='red', linewidth=0.5, alpha=0.5)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

plt.show()

# %%
# 4. Write a Python programming to display a bar chart of the popularity of programming Languages. Use different color for each bar.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

prmng_lang = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity= [22.2, 17.6, 8.8, 8, 7.7, 6.7]
colors = ['red','black', 'green', 'blue', 'yellow', 'skyblue']

plt.bar(prmng_lang, popularity, color=colors,zorder=3)
plt.title("Popularity of Programming Language Worldwide,\n Oct 2017 compared to a year ago")
plt.xlabel("Language")
plt.ylabel("Popularity")

# plt.xlim(-.4,5.4)
# plt.ylim(0,25)

#plt.minorticks_on()
plt.grid(which='both', color='grey')
# plt.grid(which='major', color='red')

plt.show()

# %%
# 5. Write a Python programming to display a bar chart of the popularity of programming Languages. Attach a text label above each bar displaying its popularity (float value).
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

prmng_lang = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity= [22.2, 17.6, 8.8, 8, 7.7, 6.7]

bars = plt.bar(prmng_lang, popularity, color='blue', zorder=3)
plt.title('Popularity of Programming Languages')
plt.xlabel("Language")
plt.ylabel("Popularity")
plt.xlim(-.4,5.4)
plt.ylim(0,25)

plt.minorticks_on()
plt.grid(which='minor', color='grey', linewidth=0.3)
plt.grid(which='major', color='red', linewidth=0.5, alpha=0.5)
plt.grid(True, which='both', linewidth=0.5)
plt.bar_label(bars, fmt='%.2f')

plt.show()

# %%
# 6. Write a Python programming to display a bar chart of the popularity of programming Languages. Make blue border to each bar.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

prmng_lang = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity= [22.2, 17.6, 8.8, 8, 7.7, 6.7]

plt.bar(prmng_lang, popularity, color='#4B8FD8', edgecolor='blue', zorder=3)
plt.title("Popularity of Programming Language Worldwide,\n Oct 2017 compared to a year ago")
plt.xlabel("Language")
plt.ylabel("Popularity")

plt.xlim(-.4,5.4)
plt.ylim(0,25)

plt.minorticks_on()
plt.grid(which='minor', color='grey', linewidth=0.3)
plt.grid(which='major', color='red', linewidth=0.5, alpha=0.5)

plt.show()

# %%
# 7. Write a Python programming to display a bar chart of the popularity of programming Languages. 
# Specify the position of each bar plot.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

prmng_lang = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

data = sorted(zip(popularity, prmng_lang), reverse=True)
sorted_popularity, sorted_languages = zip(*data)

positions = [1,2,5,8,10,11]

plt.bar(positions, sorted_popularity, color='blue', zorder=3)

plt.title('Popularity of Programming Languages (Ranked)')
plt.xlabel('Programming Languages')
plt.ylabel('Popularity (%)')

# plt.xlim(-.5,11)
# plt.ylim(6,25)

plt.minorticks_on()
plt.grid(which='minor', color='grey', linewidth=0.3)
plt.grid(which='major', color='red', linewidth=0.5, alpha=0.5)

plt.xticks(positions, sorted_languages)
plt.show()

# %%
# 8. Write a Python programming to display a bar chart of the popularity of programming Languages. Select the width of each bar and their positions.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

prmng_lang = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

data = sorted(zip(popularity, prmng_lang), reverse=True)
sorted_popularity, sorted_languages = zip(*data)

positions = [1,2,5,8,10,11]
width = [0.3,0.5,0.9,1.5,0.3,0.5]

plt.bar(positions, sorted_popularity, color='blue', zorder=3, width=width)

plt.title('Popularity of Programming Languages (Ranked)')
plt.xlabel('Programming Languages')
plt.ylabel('Popularity (%)')

# plt.xlim(-.5,11)
# plt.ylim(6,25)

plt.minorticks_on()
plt.grid(which='minor', color='grey', linewidth=0.3)
plt.grid(which='major', color='red', linewidth=0.5, alpha=0.5)

plt.xticks(positions, sorted_languages)
plt.show()

# %%
# 9. Write a Python programming to display a bar chart of the popularity of programming Languages. Increase bottom margin.
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

prmng_lang = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity= [22.2, 17.6, 8.8, 8, 7.7, 6.7]

plt.bar(prmng_lang, popularity, color='#4B8FD8', edgecolor='blue', zorder=3)
plt.title("Popularity of Programming Language Worldwide,\n Oct 2017 compared to a year ago")
plt.xlabel("Language")
plt.ylabel("Popularity")

plt.xlim(-.4,5.4)
plt.ylim(0,25)

plt.minorticks_on()
plt.grid(which='minor', color='grey', linewidth=0.3)
plt.grid(which='major', color='red', linewidth=0.5, alpha=0.5)
plt.xticks(rotation=90)
plt.subplots_adjust(bottom=0.5)       # 

plt.show()

# %%
# 10. Write a Python program to create bar plot of scores by group and gender. 
# Use multiple X values on the same chart for men and women.
# Sample Data:
# Means (men) = (22, 30, 35, 35, 26)
# Means (women) = (25, 32, 30, 35, 29)

men_Means = [22, 30, 35, 35, 26]
women_Means = [25, 32, 30, 35, 29]

groups = np.arange(len(men_Means))

width = 0.35  

fig, ax = plt.subplots()

pl1 = ax.bar(groups - width/2, men_Means, width, color='green', edgecolor='blue', label='Men', zorder=3)
pl2 = ax.bar(groups + width/2, women_Means, width, color='red', edgecolor='blue', label='Women', zorder=3)

ax.set_title("Score by Person")
ax.set_xlabel("Person")
ax.set_ylabel("Scores")
ax.set_xticks(groups)
ax.set_xticklabels(['G1', 'G2', 'G3', 'G4', 'G5'])

ax.legend()

plt.tight_layout()
plt.show()

# %%
# 11. Write a Python program to create bar plot from a DataFrame.
# Sample Data Frame:
#   a b c d e
# 2 4,8,5,7,6
# 4 2,3,4,2,6
# 6 4,7,4,7,8
# 8 2,6,4,8,6
# 10 2,4,3,3,2

data = {
    'a': [4, 2, 4, 2, 2],
    'b': [8, 3, 7, 6, 4],
    'c': [5, 4, 4, 4, 3],
    'd': [7, 2, 7, 8, 3],
    'e': [6, 6, 8, 6, 2]
}
df = pd.DataFrame(data, index=[2, 4, 6, 8, 10])
colors = ['blue','green', 'red', 'aqua', 'purple']
plt.figure(figsize=(6,8))
df.plot(kind='bar', figsize=(8,5), color= colors, zorder=3)
plt.xticks()
plt.title('Bar Plot')

plt.minorticks_on()
plt.grid(which='minor', color='grey', linewidth=0.3)
plt.grid(which='major', color='red', linewidth=0.5, alpha=0.5)
plt.legend()
plt.grid()
ax.legend()
plt.show()

# %%
# 12. Write a Python program to create bar plots with error bars on the same figure.
# Sample Date
# Mean velocity: 0.2474, 0.1235, 0.1737, 0.1824
# Standard deviation of velocity: 0.3314, 0.2278, 0.2836, 0.2645


mean_velocity = [24.74, 12.35, 17.37, 18.24]
sd_of_velocity = [33.14, 22.78, 28.36, 26.45]

error = [3.314, 2.278, 2.836, 2.645]


plt.bar(sd_of_velocity, mean_velocity, color='red', edgecolor='blue', yerr= error, zorder=3)
plt.minorticks_on()
plt.grid(which='minor', color='grey', linewidth=0.3)
plt.grid(which='major', color='red', linewidth=0.5, alpha=0.5)
plt.title("Scores by Velocity")
plt.xlabel("Velocity")
plt.ylabel("Scores")
plt.show()

# %%
# 13. Write a Python program to create bar plots with errorbars on the same 
# figure. Attach a text label above each bar displaying men means (integer 
# value).
# Sample Data
# Mean velocity: 0.2474, 0.1235, 0.1737, 0.1824
# Standard deviation of velocity: 0.3314, 0.2278, 0.2836, 0.2645

mean_velocity = [24.74, 12.35, 17.37, 18.24]
sd_of_velocity = [33.14, 22.78, 28.36, 26.45]

error = [3.314, 2.278, 2.836, 2.645]


bars = plt.bar(sd_of_velocity, mean_velocity, color='red', edgecolor='blue', yerr= error)
plt.bar_label(bars)

plt.title("Scores by Velocity")
plt.xlabel("Velocity")
plt.ylabel("Scores")
plt.show()

# %%
# 14. Write a Python program to create a stacked bar plot with error bars.
# Note: Use bottom to stack the women?s bars on top of the men?s bars.
# Sample Data:
# Means (men) = (22, 30, 35, 35, 26)
# Means (women) = (25, 32, 30, 35, 29)
# Men Standard deviation = (4, 3, 4, 1, 5)
# Women Standard deviation = (3, 5, 2, 3, 3)

means_men = [22, 30, 35, 35, 26]
means_women = [25, 32, 30, 35, 29]
men_sd = [4, 3, 4, 1, 5]
women_sd = [3, 5, 2, 3, 3]

df = pd.DataFrame({'Men': means_men, 'Women': means_women})
df.plot(kind='bar', yerr=[men_sd, women_sd], stacked=True)
plt.show()

# %%
# 15. Write a Python program to create a horizontal bar chart with differently ordered colors.
# Note: Use bottom to stack the women?s bars on top of the men?s bars.
# Sample Data Set:
# languages = [['Language','Science','Math'],
# ['Science','Math','Language'],
# ['Math','Language','Science']]
# numbers = [{'Language':75, 'Science':88, 'Math':96},
# {'Language':71, 'Science':95, 'Math':92},
# {'Language':75, 'Science':90, 'Math':89}]


languages = [['Language', 'Science', 'Math'],
             ['Science', 'Math', 'Language'],
             ['Math', 'Language', 'Science']]
numbers = [{'Language': 75, 'Science': 88, 'Math': 96},
           {'Language': 71, 'Science': 95, 'Math': 92},
           {'Language': 75, 'Science': 90, 'Math': 89}]

colors = ['r', 'g', 'b']

names = sorted(numbers[0].keys())
values = np.array([[data[name] for name in order] for data, order in zip(numbers, languages)])
lefts = np.insert(np.cumsum(values, axis=1), 0, 0, axis=1)[:, :-1]
orders = np.array(languages)
bottoms = np.arange(len(languages))

for name, color in zip(names, colors):
    idx = np.where(orders == name)
    value = values[idx]
    left = lefts[idx]
    plt.barh(bottoms, value, left=left, color=color, label=name)

plt.yticks(bottoms, [f'Student-{i+1}' for i in bottoms])
plt.legend(loc='best', bbox_to_anchor=(1.0, 1.0))
plt.subplots_adjust(right=0.75)
plt.xlabel('Scores')
plt.show()

# %%
# 16. Write a Python program to create stack bar plot and add label to each section.
# Sample data:
# people = ('G1','G2','G3','G4','G5','G6','G7','G8')
# segments = 4
# # multi-dimensional data
# data = [[ 3.40022085, 7.70632498, 6.4097905, 10.51648577, 7.5330039, 
# 7.1123587, 12.77792868, 3.44773477],
# [ 11.24811149, 5.03778215, 6.65808464, 12.32220677, 7.45964195, 
# 6.79685302, 7.24578743, 3.69371847],
# [ 3.94253354, 4.74763549, 11.73529246, 4.6465543, 12.9952182, 
# 4.63832778, 11.16849999, 8.56883433],
# [ 4.24409799, 12.71746612, 11.3772169, 9.00514257, 10.47084185, 
# 10.97567589, 3.98287652, 8.80552122]]


import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

people = ['G1','G2','G3','G4','G5','G6','G7','G8']
segments = 4
data = [[ 3.40022085, 7.70632498, 6.4097905, 10.51648577, 7.5330039, 
7.1123587, 12.77792868, 3.44773477],
[ 11.24811149, 5.03778215, 6.65808464, 12.32220677, 7.45964195, 
6.79685302, 7.24578743, 3.69371847],
[ 3.94253354, 4.74763549, 11.73529246, 4.6465543, 12.9952182, 
4.63832778, 11.16849999, 8.56883433],
[ 4.24409799, 12.71746612, 11.3772169, 9.00514257, 10.47084185, 
10.97567589, 3.98287652, 8.80552122]]

df = pd.DataFrame(data).transpose()
bars = df.plot(kind='barh', stacked=True)
for i in range(len(df)):
    bottoms = 0  
    for j in range(len(df.columns)):
        height = df.iloc[i, j]
        percentage = height / df.iloc[i].sum() * 100
        bars.text(height + bottoms, i, f'{percentage:.2f}%', ha='right', va='center', color='black')
        bottoms += height  

plt.tight_layout()
plt.xlabel("Scores")
plt.ylabel("Groups")
plt.show()

# %%
# 17. Write a Python program to add textures (black and white) to bars and wedges.
# Note: Use bottom to stack the womens bars on top of the mens bars.
