# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# 1. Write a Pandas program to detect missing values of a given DataFrame. 
# Display True or False.
# Test Data:
#  ord_no purch_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 2012-10-05 3002 5002.0
# 1 NaN 270.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN 3001 5001.0
# 3 70004.0 110.50 2012-08-17 3003 NaN
# 4 NaN 948.50 2012-09-10 3002 5002.0
# 5 70005.0 2400.60 2012-07-27 3001 5001.0
# 6 NaN 5760.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 2012-10-10 3004 NaN
# 8 70003.0 2480.40 2012-10-10 3003 5003.0
# 9 70012.0 250.45 2012-06-27 3002 5002.0
# 10 NaN 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 2012-04-25 3001 NaN
df = pd.read_csv('assignment-7.csv', sep=' ', index_col='Unnamed: 0')
df.isnull()
# Out:
#     ord_no  purch_amt  ord_date  customer_id  salesman_id
# 0    False      False     False        False        False
# 1     True      False     False        False        False
# 2    False      False      True        False        False
# 3    False      False     False        False         True
# 4     True      False     False        False        False
# 5    False      False     False        False        False
# 6     True      False     False        False        False
# 7    False      False     False        False         True
# 8    False      False     False        False        False
# 9    False      False     False        False        False
# 10    True      False     False        False        False
# 11   False      False     False        False         True

# %%
# 2. Write a Pandas program to identify the column(s) of a given DataFrame which 
# have at least one missing value.
# Test Data:
#  ord_no purch_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 2012-10-05 3002 5002.0
# 1 NaN 270.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN 3001 5001.0
# 3 70004.0 110.50 2012-08-17 3003 NaN
# 4 NaN 948.50 2012-09-10 3002 5002.0
# 5 70005.0 2400.60 2012-07-27 3001 5001.0
# 6 NaN 5760.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 2012-10-10 3004 NaN
# 8 70003.0 2480.40 2012-10-10 3003 5003.0
# 9 70012.0 250.45 2012-06-27 3002 5002.0
# 10 NaN 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 2012-04-25 3001 NaN
df.ord_no.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 12 entries, 0 to 11
# Series name: ord_no
# Non-Null Count  Dtype
# --------------  -----
# 8 non-null      float64
# dtypes: float64(1)
# memory usage: 192.0 bytes

# %%
# 3. Write a Pandas program to count the number of missing values in each 
# column of a given DataFrame.
# Test Data:
#  ord_no purch_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 2012-10-05 3002 5002.0
# 1 NaN 270.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN 3001 5001.0
# 3 70004.0 110.50 2012-08-17 3003 NaN
# 4 NaN 948.50 2012-09-10 3002 5002.0
# 5 70005.0 2400.60 2012-07-27 3001 5001.0
# 6 NaN 5760.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 2012-10-10 3004 NaN
# 8 70003.0 2480.40 2012-10-10 3003 5003.0
# 9 70012.0 250.45 2012-06-27 3002 5002.0
# 10 NaN 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 2012-04-25 3001 NaN
print('Column:  Missing Count')
df.isnull().sum()
# Out:
# Column:  Missing Count
# ord_no         4
# purch_amt      0
# ord_date       1
# customer_id    0
# salesman_id    3
# dtype: int64

# %%
# 4. Write a Pandas program to find and replace the missing values in a given 
# DataFrame which do not have any valuable information.
# Test Data:
#  ord_no purch_amt ord_date customer_id salesman_id
# 0 70001 150.5 ? 3002 5002
# 1 NaN 270.65 2012-09-10 3001 5003
# 2 70002 65.26 NaN 3001 ?
# 3 70004 110.5 2012-08-17 3003 5001
# 4 NaN 948.5 2012-09-10 3002 NaN
# 5 70005 2400.6 2012-07-27 3001 5002
# 6 -- 5760 2012-09-10 3001 5001
# 7 70010 ? 2012-10-10 3004 ?
# 8 70003 12.43 2012-10-10 -- 5003
# 9 70012 2480.4 2012-06-27 3002 5002
# 10 NaN 250.45 2012-08-17 3001 5003
# 11 70013 3045.6 2012-04-25 3001 --


df1 = pd.read_csv('assignment-7.1.csv', sep=' ', index_col='Unnamed: 0')

df1 = df1.replace({'NaN':'NaN' , '--': 'NaN', '?': 'NaN'})
df1['ord_no'] = pd.to_numeric(df['ord_no'], errors='coerce')
df1['purch_amt'] = pd.to_numeric(df['purch_amt'], errors='coerce')
df1['customer_id'] = pd.to_numeric(df['customer_id'], errors='coerce')
df1['salesman_id'] = pd.to_numeric(df['salesman_id'], errors='coerce')
df1['ord_date'] = pd.to_datetime(df['ord_date'] , format='%Y-%m-%d',errors='coerce')


df1.fillna({'ord_no':round(df1['ord_no'].mean())} , inplace=True)
df1.fillna({'purch_amt':round(df1['purch_amt'].mean())} , inplace=True)
df1.fillna({'ord_date':pd.Timestamp('2023-01-01')} , inplace=True)
df1.fillna({'customer_id':round(df1['customer_id'].mean())} , inplace=True)
df1.fillna({'salesman_id':round(df1['salesman_id'].mean())} , inplace=True)

df1
# Out:
#      ord_no  purch_amt   ord_date  customer_id  salesman_id
# 0   70001.0     150.50 2012-10-05         3002       5002.0
# 1   70006.0     270.65 2012-09-10         3001       5003.0
# 2   70002.0      65.26 2023-01-01         3001       5001.0
# 3   70004.0     110.50 2012-08-17         3003       5002.0
# 4   70006.0     948.50 2012-09-10         3002       5002.0
# 5   70005.0    2400.60 2012-07-27         3001       5001.0
# 6   70006.0    5760.00 2012-09-10         3001       5001.0
# 7   70010.0    1983.43 2012-10-10         3004       5002.0
# 8   70003.0    2480.40 2012-10-10         3003       5003.0
# 9   70012.0     250.45 2012-06-27         3002       5002.0
# 10  70006.0      75.29 2012-08-17         3001       5003.0
# 11  70013.0    3045.60 2012-04-25         3001       5002.0

# %%
# 5. Write a Pandas program to drop the rows where at least one element is 
# missing in a given DataFrame.
# Test Data:
#  ord_no purch_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 2012-10-05 3002 5002.0
# 1 NaN 270.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN 3001 5001.0
# 3 70004.0 110.50 2012-08-17 3003 NaN
# 4 NaN 948.50 2012-09-10 3002 5002.0
# 5 70005.0 2400.60 2012-07-27 3001 5001.0
# 6 NaN 5760.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 2012-10-10 3004 NaN
# 8 70003.0 2480.40 2012-10-10 3003 5003.0
# 9 70012.0 250.45 2012-06-27 3002 5002.0
# 10 NaN 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 2012-04-25 3001 NaN

df2 = df
df2.dropna()
# Out:
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0  70001.0     150.50  2012-10-05         3002       5002.0
# 5  70005.0    2400.60  2012-07-27         3001       5001.0
# 8  70003.0    2480.40  2012-10-10         3003       5003.0
# 9  70012.0     250.45  2012-06-27         3002       5002.0

# %%
# 6. Write a Pandas program to drop the columns where at least one element is 
# missing in a given DataFrame.
# Test Data:
#  ord_no purch_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 2012-10-05 3002 5002.0
# 1 NaN 270.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN 3001 5001.0
# 3 70004.0 110.50 2012-08-17 3003 NaN
# 4 NaN 948.50 2012-09-10 3002 5002.0
# 5 70005.0 2400.60 2012-07-27 3001 5001.0
# 6 NaN 5760.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 2012-10-10 3004 NaN
# 8 70003.0 2480.40 2012-10-10 3003 5003.0
# 9 70012.0 250.45 2012-06-27 3002 5002.0
# 10 NaN 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 2012-04-25 3001 NaN

df3 = df
df3.dropna(axis=1)
# Out:
#     purch_amt  customer_id
# 0      150.50         3002
# 1      270.65         3001
# 2       65.26         3001
# 3      110.50         3003
# 4      948.50         3002
# 5     2400.60         3001
# 6     5760.00         3001
# 7     1983.43         3004
# 8     2480.40         3003
# 9      250.45         3002
# 10      75.29         3001
# 11    3045.60         3001

# %%
# 7. Write a Pandas program to drop the rows where all elements are missing in a 
# given DataFrame.
# Test Data:
#  ord_no purch_amt ord_date customer_id
# 0 NaN NaN NaN NaN
# 1 NaN 270.65 2012-09-10 3001.0
# 2 70002.0 65.26 NaN 3001.0
# 3 70004.0 110.50 2012-08-17 3003.0
# 4 NaN 948.50 2012-09-10 3002.0
# 5 70005.0 2400.60 2012-07-27 3001.0
# 6 NaN 5760.00 2012-09-10 3001.0
# 7 70010.0 1983.43 2012-10-10 3004.0
# 8 70003.0 2480.40 2012-10-10 3003.0
# 9 70012.0 250.45 2012-06-27 3002.0
# 10 NaN 75.29 2012-08-17 3001.0
# 11 70013.0 3045.60 2012-04-25 3001.0

df4 = pd.read_csv('assignment-7.2.csv', sep=' ', index_col='Unnamed: 0')
df4.dropna(how='all')
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3   70004.0     110.50  2012-08-17       3003.0
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11  70013.0    3045.60  2012-04-25       3001.0

# %%
# 8. Write a Pandas program to keep the rows with at least 2 NaN values in a given 
# DataFrame.
# Test Data:
#  ord_no purch_amt ord_date customer_id
# 0 NaN NaN NaN NaN
# 1 NaN 270.65 2012-09-10 3001.0
# 2 70002.0 65.26 NaN 3001.0
# 3 NaN NaN NaN NaN
# 4 NaN 948.50 2012-09-10 3002.0
# 5 70005.0 2400.60 2012-07-27 3001.0
# 6 NaN 5760.00 2012-09-10 3001.0
# 7 70010.0 1983.43 2012-10-10 3004.0
# 8 70003.0 2480.40 2012-10-10 3003.0
# 9 70012.0 250.45 2012-06-27 3002.0
# 10 NaN 75.29 2012-08-17 3001.0
# 11 NaN NaN NaN NaN

df4 = pd.read_csv('assignment-7.3.csv', sep=' ', index_col='Unnamed: 0')
df4.dropna(thresh=df4.shape[1]-2)
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0

# %%
# 9. Write a Pandas program to drop those rows from a given DataFrame in which 
# specific columns have missing values.
# Test Data:
#  ord_no purch_amt ord_date customer_id
# 0 NaN NaN NaN NaN
# 1 NaN 270.65 2012-09-10 3001.0
# 2 70002.0 65.26 NaN 3001.0
# 3 NaN NaN NaN NaN
# 4 NaN 948.50 2012-09-10 3002.0
# 5 70005.0 2400.60 2012-07-27 3001.0
# 6 NaN 5760.00 2012-09-10 3001.0
# 7 70010.0 1983.43 2012-10-10 3004.0
# 8 70003.0 2480.40 2012-10-10 3003.0
# 9 70012.0 250.45 2012-06-27 3002.0
# 10 NaN 75.29 2012-08-17 3001.0
# 11 NaN NaN NaN NaN

# drop rows of specfic column ord_no
df5 = pd.read_csv('assignment-7.3.csv', sep=' ', index_col='Unnamed: 0')
df5 = df5[df5['ord_no'].notna()]
df5

df5 = df5[df5['ord_date'].notna()]
df5
# Out:
#     ord_no  purch_amt    ord_date  customer_id
# 5  70005.0    2400.60  2012-07-27       3001.0
# 7  70010.0    1983.43  2012-10-10       3004.0
# 8  70003.0    2480.40  2012-10-10       3003.0
# 9  70012.0     250.45  2012-06-27       3002.0

# %%
# 10. Write a Pandas program to keep the valid entries of a given DataFrame.
# Test Data:
#  ord_no purch_amt ord_date customer_id
# 0 NaN NaN NaN NaN
# 1 NaN 270.65 2012-09-10 3001.0
# 2 70002.0 65.26 NaN 3001.0
# 3 NaN NaN NaN NaN
# 4 NaN 948.50 2012-09-10 3002.0
# 5 70005.0 2400.60 2012-07-27 3001.0
# 6 NaN 5760.00 2012-09-10 3001.0
# 7 70010.0 1983.43 2012-10-10 3004.0
# 8 70003.0 2480.40 2012-10-10 3003.0
# 9 70012.0 250.45 2012-06-27 3002.0
# 10 NaN 75.29 2012-08-17 3001.0
# 11 NaN NaN NaN NaN

df5 = pd.read_csv('assignment-7.3.csv', sep=' ', index_col='Unnamed: 0')
df5.dropna()
# Out:
#     ord_no  purch_amt    ord_date  customer_id
# 5  70005.0    2400.60  2012-07-27       3001.0
# 7  70010.0    1983.43  2012-10-10       3004.0
# 8  70003.0    2480.40  2012-10-10       3003.0
# 9  70012.0     250.45  2012-06-27       3002.0

# %%
# 11. Write a Pandas program to calculate the total number of missing values in a 
# DataFrame.
# Test Data:
#  ord_no purch_amt ord_date customer_id
# 0 NaN NaN NaN NaN
# 1 NaN 270.65 2012-09-10 3001.0
# 2 70002.0 65.26 NaN 3001.0
# 3 NaN NaN NaN NaN
# 4 NaN 948.50 2012-09-10 3002.0
# 5 70005.0 2400.60 2012-07-27 3001.0
# 6 NaN 5760.00 2012-09-10 3001.0
# 7 70010.0 1983.43 2012-10-10 3004.0
# 8 70003.0 2480.40 2012-10-10 3003.0
# 9 70012.0 250.45 2012-06-27 3002.0
# 10 NaN 75.29 2012-08-17 3001.0
# 11 NaN NaN NaN NaN

df5 = pd.read_csv('assignment-7.3.csv', sep=' ', index_col='Unnamed: 0')
print(f'Total no of Missing values: {df5.isnull().sum().sum()}')
df5
# Out:
# Total no of Missing values: 17
#      ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3       NaN        NaN         NaN          NaN
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11      NaN        NaN         NaN          NaN

# %%
# 12. Write a Pandas program to replace NaNs with a single constant value in 
# specified columns in a DataFrame.
# Test Data:
#  ord_no purch_amt ord_date customer_id
# 0 NaN NaN NaN NaN
# 1 NaN 270.65 2012-09-10 3001.0
# 2 70002.0 65.26 NaN 3001.0
# 3 NaN NaN NaN NaN
# 4 NaN 948.50 2012-09-10 3002.0
# 5 70005.0 2400.60 2012-07-27 3001.0
# 6 NaN 5760.00 2012-09-10 3001.0
# 7 70010.0 1983.43 2012-10-10 3004.0
# 8 70003.0 2480.40 2012-10-10 3003.0
# 9 70012.0 250.45 2012-06-27 3002.0
# 10 NaN 75.29 2012-08-17 3001.0
# 11 NaN NaN NaN NaN


df5.fillna({'ord_no': 70005}, inplace=True)
df5
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 0   70005.0        NaN         NaN          NaN
# 1   70005.0     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3   70005.0        NaN         NaN          NaN
# 4   70005.0     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6   70005.0    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10  70005.0      75.29  2012-08-17       3001.0
# 11  70005.0        NaN         NaN          NaN

# %%
# 13. Write a Pandas program to replace NaNs with the value from the previous 
# row or the next row in a given DataFrame.
# Test Data:
#  ord_no purch_amt sale_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 10.50 2012-10-05 3002 5002.0
# 1 NaN NaN 20.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN NaN 3001 5001.0
# 3 70004.0 110.50 11.50 2012-08-17 3003 NaN
# 4 NaN 948.50 98.50 2012-09-10 3002 5002.0
# 5 70005.0 NaN NaN 2012-07-27 3001 5001.0
# 6 NaN 5760.00 57.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 19.43 2012-10-10 3004 NaN
# 8 70003.0 NaN NaN 2012-10-10 3003 5003.0
# 9 70012.0 250.45 25.45 2012-06-27 3002 5002.0
# 10 NaN 75.29 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 35.60 2012-04-25 3001 NaN 

df5 = pd.read_csv('assignment-7.4.csv', sep=' ', index_col='Unnamed: 0')
df['purch_amt'] = df5['purch_amt'].ffill(inplace=True)
df5
# Out:
# C:\Users\DAI.STUDENTSDC\AppData\Local\Temp\ipykernel_14220\140274806.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['purch_amt'] = df5['purch_amt'].ffill(inplace=True)
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN     150.50     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0     948.50       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0    1983.43       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN

# %%
# 14. Write a Pandas program to replace NaNs with median or mean of the 
# specified columns in a given DataFrame.
# Test Data:
#  ord_no purch_amt sale_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 10.50 2012-10-05 3002 5002.0
# 1 NaN NaN 20.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN NaN 3001 5001.0
# 3 70004.0 110.50 11.50 2012-08-17 3003 NaN
# 4 NaN 948.50 98.50 2012-09-10 3002 5002.0
# 5 70005.0 NaN NaN 2012-07-27 3001 5001.0
# 6 NaN 5760.00 57.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 19.43 2012-10-10 3004 NaN
# 8 70003.0 NaN NaN 2012-10-10 3003 5003.0
# 9 70012.0 250.45 25.45 2012-06-27 3002 5002.0
# 10 NaN 75.29 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 35.60 2012-04-25 3001 NaN

df5.fillna({'sale_amt': df5['sale_amt'].mean()})
# Out:
#      ord_no  purch_amt   sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  10.500000  2012-10-05         3002       5002.0
# 1       NaN     150.50  20.650000  2012-09-10         3001       5003.0
# 2   70002.0      65.26  39.324444         NaN         3001       5001.0
# 3   70004.0     110.50  11.500000  2012-08-17         3003          NaN
# 4       NaN     948.50  98.500000  2012-09-10         3002       5002.0
# 5   70005.0     948.50  39.324444  2012-07-27         3001       5001.0
# 6       NaN    5760.00  57.000000  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  19.430000  2012-10-10         3004          NaN
# 8   70003.0    1983.43  39.324444  2012-10-10         3003       5003.0
# 9   70012.0     250.45  25.450000  2012-06-27         3002       5002.0
# 10      NaN      75.29  75.290000  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  35.600000  2012-04-25         3001          NaN

# %%
# 15. Write a Pandas program to interpolate the missing values using the Linear 
# Interpolation method in a given DataFrame.
# From Wikipedia, in mathematics, linear interpolation is a method of curve fitting 
# using linear polynomials to construct new data points within the range of a 
# discrete set of known data points.
# Test Data:
#  ord_no purch_amt sale_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 10.50 2012-10-05 3002 5002.0
# 1 NaN NaN 20.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN NaN 3001 5001.0
# 3 70004.0 110.50 11.50 2012-08-17 3003 NaN
# 4 NaN 948.50 98.50 2012-09-10 3002 5002.0
# 5 70005.0 NaN NaN 2012-07-27 3001 5001.0
# 6 NaN 5760.00 57.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 19.43 2012-10-10 3004 NaN
# 8 70003.0 NaN NaN 2012-10-10 3003 5003.0
# 9 70012.0 250.45 25.45 2012-06-27 3002 5002.0
# 10 NaN 75.29 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 35.60 2012-04-25 3001 NaN

df5 = pd.read_csv('assignment-7.4.csv', sep=' ', index_col='Unnamed: 0')
df5['ord_date'] = pd.to_datetime(df5['ord_date'] , format='%Y-%m-%d',errors='coerce')
df5 = df5.interpolate(method='linear')
df5
# Out:
#      ord_no  purch_amt  sale_amt   ord_date  customer_id  salesman_id
# 0   70001.0     150.50    10.500 2012-10-05         3002       5002.0
# 1   70001.5     107.88    20.650 2012-09-10         3001       5003.0
# 2   70002.0      65.26    16.075 2012-08-29         3001       5001.0
# 3   70004.0     110.50    11.500 2012-08-17         3003       5001.5
# 4   70004.5     948.50    98.500 2012-09-10         3002       5002.0
# 5   70005.0    3354.25    77.750 2012-07-27         3001       5001.0
# 6   70007.5    5760.00    57.000 2012-09-10         3001       5001.0
# 7   70010.0    1983.43    19.430 2012-10-10         3004       5002.0
# 8   70003.0    1116.94    22.440 2012-10-10         3003       5003.0
# 9   70012.0     250.45    25.450 2012-06-27         3002       5002.0
# 10  70012.5      75.29    75.290 2012-08-17         3001       5003.0
# 11  70013.0    3045.60    35.600 2012-04-25         3001       5003.0

# %%
# 16. Write a Pandas program to count the number of missing values of a specified 
# column in a given DataFrame.
# Test Data:
#  ord_no purch_amt sale_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 10.50 2012-10-05 3002 5002.0
# 1 NaN NaN 20.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN NaN 3001 5001.0
# 3 70004.0 110.50 11.50 2012-08-17 3003 NaN
# 4 NaN 948.50 98.50 2012-09-10 3002 5002.0
# 5 70005.0 NaN NaN 2012-07-27 3001 5001.0
# 6 NaN 5760.00 57.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 19.43 2012-10-10 3004 NaN
# 8 70003.0 NaN NaN 2012-10-10 3003 5003.0
# 9 70012.0 250.45 25.45 2012-06-27 3002 5002.0
# 10 NaN 75.29 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 35.60 2012-04-25 3001 NaN

df5 = pd.read_csv('assignment-7.4.csv', sep=' ', index_col='Unnamed: 0')
print(f'No of missing values in ord_no : {df5['ord_no'].isna().sum()}')
# Out:
# No of missing values in ord_no : 4

# %%
# 17. Write a Pandas program to count the missing values in a given DataFrame.
# Test Data:
#  ord_no purch_amt sale_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 10.50 2012-10-05 3002 5002.0
# 1 NaN NaN 20.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN NaN 3001 5001.0
# 3 70004.0 110.50 11.50 2012-08-17 3003 NaN
# 4 NaN 948.50 98.50 2012-09-10 3002 5002.0
# 5 70005.0 NaN NaN 2012-07-27 3001 5001.0
# 6 NaN 5760.00 57.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 19.43 2012-10-10 3004 NaN
# 8 70003.0 NaN NaN 2012-10-10 3003 5003.0
# 9 70012.0 250.45 25.45 2012-06-27 3002 5002.0
# 10 NaN 75.29 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 35.60 2012-04-25 3001 NaN

print(f'Total no of Missing values in given DataFrame: {df5.isnull().sum().sum()}')
# Out:
# Total no of Missing values in given DataFrame: 14

# %%
# 18. Write a Pandas program to find the Indexes of missing values in a given DataFrame.
# Test Data:
#  ord_no purch_amt sale_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 10.50 2012-10-05 3002 5002.0
# 1 NaN NaN 20.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN NaN 3001 5001.0
# 3 70004.0 110.50 11.50 2012-08-17 3003 NaN
# 4 NaN 948.50 98.50 2012-09-10 3002 5002.0
# 5 70005.0 NaN NaN 2012-07-27 3001 5001.0
# 6 NaN 5760.00 57.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 19.43 2012-10-10 3004 NaN
# 8 70003.0 NaN NaN 2012-10-10 3003 5003.0
# 9 70012.0 250.45 25.45 2012-06-27 3002 5002.0
# 10 NaN 75.29 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 35.60 2012-04-25 3001 NaN

df5.index[df5.isnull().any(axis=1)].tolist()
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 10, 11]

# %%
# 19. Write a Pandas program to replace the missing values with the most frequent 
# values present in each column of a given DataFrame.
# Test Data:
#  ord_no purch_amt sale_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 10.50 2012-10-05 3002 5002.0
# 1 NaN NaN 20.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN NaN 3001 5001.0
# 3 70004.0 110.50 11.50 2012-08-17 3003 NaN
# 4 NaN 948.50 98.50 2012-09-10 3002 5002.0
# 5 70005.0 NaN NaN 2012-07-27 3001 5001.0
# 6 NaN 5760.00 57.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 19.43 2012-10-10 3004 NaN
# 8 70003.0 NaN NaN 2012-10-10 3003 5003.0
# 9 70012.0 250.45 25.45 2012-06-27 3002 5002.0
# 10 NaN 75.29 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 35.60 2012-04-25 3001 NaN

def replace_with_mode(series):
    mode = series.mode()
    if len(mode) > 1:
        return mode[0]
    return mode[0]

df5 = df5.apply(lambda x: x.fillna(replace_with_mode(x)), axis=0)
df5
# Out:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1   70001.0      65.26     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26     10.50  2012-09-10         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003       5001.0
# 4   70001.0     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0      65.26     10.50  2012-07-27         3001       5001.0
# 6   70001.0    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004       5001.0
# 8   70003.0      65.26     10.50  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10  70001.0      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001       5001.0

# %%
# 20. Write a Pandas program to create a heatmap for more information about the 
# distribution of missing values in a given DataFrame.
# Test Data:
#  ord_no purch_amt sale_amt ord_date customer_id salesman_id
# 0 70001.0 150.50 10.50 2012-10-05 3002 5002.0
# 1 NaN NaN 20.65 2012-09-10 3001 5003.0
# 2 70002.0 65.26 NaN NaN 3001 5001.0
# 3 70004.0 110.50 11.50 2012-08-17 3003 NaN
# 4 NaN 948.50 98.50 2012-09-10 3002 5002.0
# 5 70005.0 NaN NaN 2012-07-27 3001 5001.0
# 6 NaN 5760.00 57.00 2012-09-10 3001 5001.0
# 7 70010.0 1983.43 19.43 2012-10-10 3004 NaN
# 8 70003.0 NaN NaN 2012-10-10 3003 5003.0
# 9 70012.0 250.45 25.45 2012-06-27 3002 5002.0
# 10 NaN 75.29 75.29 2012-08-17 3001 5003.0
# 11 70013.0 3045.60 35.60 2012-04-25 3001 NaN

df5 = pd.read_csv('assignment-7.4.csv', sep=' ', index_col='Unnamed: 0')
# missing_count = df5.isnull().sum().reset_index()
# missing_count.columns = ['Column_Name', 'Count']
# missing_count.set_index('Column_Name', inplace=True)
plt.figure(figsize=(12,8))
sns.heatmap(df5.isnull(), cmap='viridis', cbar=False, yticklabels=True)
plt.xlabel('Missing Value')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
