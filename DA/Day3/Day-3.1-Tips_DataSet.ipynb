# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip  gender smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name     CC Number Payment ID
# ...

# %%
df.columns  # Column Name
# Out:
# Index(['total_bill', 'tip', 'gender', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index     # Index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.head(3)     # First three rows
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name     CC Number Payment ID
# 0  Christy Cunningham  3.560330e+15    Sun2959
# 1      Douglas Tucker  4.478070e+15    Sun4608
# 2      Travis Walters  6.011810e+15    Sun4458

# %%
print(df.tail(3))     # last three rows
# Out:
#      total_bill   tip  gender smoker   day    time  size  price_per_person  \
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name     CC Number Payment ID
# 241       Keith Wong  6.011890e+15    Sat3880
# 242     Dennis Dixon  4.375220e+12      Sat17
# 243  Michelle Hardin  3.511450e+15    Thur672

# %%
df.info()   # Information about the df, including data types and memory used
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   gender            244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    float64
#  10  Payment ID        244 non-null    object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 21.1+ KB

# %%
print(len(df))   # Number of rows
# Out:
# 244

# %%
df.describe()   # Statistical summary
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563495e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040732e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525320e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596450e+15

# %%
df.describe().transpose()      # Statistical summary, better organized
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563495e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040732e+13  3.525320e+15  4.553675e+15  6.596450e+15

# %%
# Select a single column
df['total_bill']     # print(df['first name'])
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
df.total_bill       # print(df.first name   # Error !!!!
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
# Select multiple columns
# Note how its a python list of column names! Thus the double brackets.
df[['total_bill','tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
# create new columns
df['tip_percentage'] = 100 * df['tip'] / df['total_bill']
df.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name     CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3.560330e+15    Sun2959        5.944673
# 1      Douglas Tucker  4.478070e+15    Sun4608       16.054159
# 2      Travis Walters  6.011810e+15    Sun4458       16.658734
# 3    Nathaniel Harris  4.676140e+15    Sun5260       13.978041
# 4        Tonya Carter  4.832730e+15    Sun2251       14.680765

# %%
df['price_per_person'] = df['total_bill'] / df['size']
df.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2          8.495000
# 1       10.34  1.66    Male     No  Sun  Dinner     3          3.446667
# 2       21.01  3.50    Male     No  Sun  Dinner     3          7.003333
# 3       23.68  3.31    Male     No  Sun  Dinner     2         11.840000
# 4       24.59  3.61  Female     No  Sun  Dinner     4          6.147500
#
#            Payer Name     CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3.560330e+15    Sun2959        5.944673
# 1      Douglas Tucker  4.478070e+15    Sun4608       16.054159
# 2      Travis Walters  6.011810e+15    Sun4458       16.658734
# 3    Nathaniel Harris  4.676140e+15    Sun5260       13.978041
# 4        Tonya Carter  4.832730e+15    Sun2251       14.680765

# %%
# adjust existing columns    rounding of float value to the 2 digit
df['price_per_person'] = np.round(df['price_per_person'],2)
df.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name     CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3.560330e+15    Sun2959        5.944673
# 1      Douglas Tucker  4.478070e+15    Sun4608       16.054159
# 2      Travis Walters  6.011810e+15    Sun4458       16.658734
# 3    Nathaniel Harris  4.676140e+15    Sun5260       13.978041
# 4        Tonya Carter  4.832730e+15    Sun2251       14.680765

# %%
# Remove Columns
df = df.drop('tip_percentage', axis=1)       # if axis is not mentioned thn it will find in the rows
df
# Out:
#      total_bill   tip  gender smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name     CC Number Payment ID
# ...

# %%
# Index
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df = df.set_index('Payment ID')
df.head()                 # here we are makind column as index and it will appear on row down from all the columns
# Out:
#             total_bill   tip  gender smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name     CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3.560330e+15
# Sun4608                 3.45      Douglas Tucker  4.478070e+15
# Sun4458                 7.00      Travis Walters  6.011810e+15
# Sun5260                11.84    Nathaniel Harris  4.676140e+15
# Sun2251                 6.15        Tonya Carter  4.832730e+15

# %%
df = df.reset_index()   # Set the default integer values
df.head()
# Out:
#   Payment ID  total_bill   tip  gender smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3    Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4    Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name     CC Number
# 0              8.49  Christy Cunningham  3.560330e+15
# 1              3.45      Douglas Tucker  4.478070e+15
# 2              7.00      Travis Walters  6.011810e+15
# 3             11.84    Nathaniel Harris  4.676140e+15
# 4              6.15        Tonya Carter  4.832730e+15

# %%
# Conditions
df['total_bill'] < 30      # True/False
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 239    True
# 240    True
# 241    True
# 242    True
# 243    True
# Name: total_bill, Length: 244, dtype: bool

# %%
bool_series = df['total_bill'] > 30     # Saving in a variable
bool_series
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Name: total_bill, Length: 244, dtype: bool

# %%
df[bool_series]          # Extracting the data which is true
# Out:
#     Payment ID  total_bill    tip  gender smoker   day    time  size  \
# 11     Sun6686       35.26   5.00  Female     No   Sun  Dinner     4
# 23      Sat239       39.42   7.58    Male     No   Sat  Dinner     4
# 39     Sat6373       31.27   5.00    Male     No   Sat  Dinner     3
# 44     Sun2274       30.40   5.60    Male     No   Sun  Dinner     4
# 47     Sun9677       32.40   6.00    Male     No   Sun  Dinner     4
# 52     Sun6165       34.81   5.20  Female     No   Sun  Dinner     4
# 56     Sat8903       38.01   3.00    Male    Yes   Sat  Dinner     4
# 59     Sat8139       48.27   6.73    Male     No   Sat  Dinner     4
# 83    Thur8801       32.68   5.00    Male    Yes  Thur   Lunch     2
# 85    Thur7972       34.83   5.17  Female     No  Thur   Lunch     4
# 95     Fri9628       40.17   4.73    Male    Yes   Fri  Dinner     4
# 102    Sat6240       44.30   2.50  Female    Yes   Sat  Dinner     3
# 112     Sun591       38.07   4.00    Male     No   Sun  Dinner     3
# ...

# %%
df[df['total_bill'] > 30]      # can write directly
# Out:
#     Payment ID  total_bill    tip  gender smoker   day    time  size  \
# 11     Sun6686       35.26   5.00  Female     No   Sun  Dinner     4
# 23      Sat239       39.42   7.58    Male     No   Sat  Dinner     4
# 39     Sat6373       31.27   5.00    Male     No   Sat  Dinner     3
# 44     Sun2274       30.40   5.60    Male     No   Sun  Dinner     4
# 47     Sun9677       32.40   6.00    Male     No   Sun  Dinner     4
# 52     Sun6165       34.81   5.20  Female     No   Sun  Dinner     4
# 56     Sat8903       38.01   3.00    Male    Yes   Sat  Dinner     4
# 59     Sat8139       48.27   6.73    Male     No   Sat  Dinner     4
# 83    Thur8801       32.68   5.00    Male    Yes  Thur   Lunch     2
# 85    Thur7972       34.83   5.17  Female     No  Thur   Lunch     4
# 95     Fri9628       40.17   4.73    Male    Yes   Fri  Dinner     4
# 102    Sat6240       44.30   2.50  Female    Yes   Sat  Dinner     3
# 112     Sun591       38.07   4.00    Male     No   Sun  Dinner     3
# ...

# %%
# Multiple conditions
df_new = df[(df['total_bill'] > 30) & (df['gender'] == 'Male')]
df_new
# Out:
#     Payment ID  total_bill    tip gender smoker   day    time  size  \
# 23      Sat239       39.42   7.58   Male     No   Sat  Dinner     4
# 39     Sat6373       31.27   5.00   Male     No   Sat  Dinner     3
# 44     Sun2274       30.40   5.60   Male     No   Sun  Dinner     4
# 47     Sun9677       32.40   6.00   Male     No   Sun  Dinner     4
# 56     Sat8903       38.01   3.00   Male    Yes   Sat  Dinner     4
# 59     Sat8139       48.27   6.73   Male     No   Sat  Dinner     4
# 83    Thur8801       32.68   5.00   Male    Yes  Thur   Lunch     2
# 95     Fri9628       40.17   4.73   Male    Yes   Fri  Dinner     4
# 112     Sun591       38.07   4.00   Male     No   Sun  Dinner     3
# 141   Thur1025       34.30   6.70   Male     No  Thur   Lunch     6
# 142   Thur3621       41.19   5.00   Male     No  Thur   Lunch     5
# 156    Sun7518       48.17   5.00   Male     No   Sun  Dinner     6
# 167    Sun3719       31.71   4.50   Male     No   Sun  Dinner     4
# ...

# %%
df_new = df[(df['total_bill'] > 30) & (df['gender'] != 'Male')]
df_new
# Out:
#     Payment ID  total_bill   tip  gender smoker   day    time  size  \
# 11     Sun6686       35.26  5.00  Female     No   Sun  Dinner     4
# 52     Sun6165       34.81  5.20  Female     No   Sun  Dinner     4
# 85    Thur7972       34.83  5.17  Female     No  Thur   Lunch     4
# 102    Sat6240       44.30  2.50  Female    Yes   Sat  Dinner     3
# 197   Thur9313       43.11  5.00  Female    Yes  Thur   Lunch     4
# 219    Sat8863       30.14  3.09  Female    Yes   Sat  Dinner     4
# 238    Sat9777       35.83  4.67  Female     No   Sat  Dinner     3
#
#      price_per_person      Payer Name     CC Number
# 11               8.82    Diane Macias  4.577820e+15
# 52               8.70    Emily Daniel  4.291280e+15
# 85               8.71     Shawna Cook  6.011790e+15
# 102             14.77   Heather Cohen  3.797710e+14
# 197             10.78     Brooke Soto  5.544900e+15
# 219              7.54    Shelby House  5.020970e+11
# 238             11.94  Kimberly Crane  6.761840e+11

# %%
df_new = df[(df['total_bill'] > 30) & ~(df['gender'] == 'Male')]
df_new
# Out:
#     Payment ID  total_bill   tip  gender smoker   day    time  size  \
# 11     Sun6686       35.26  5.00  Female     No   Sun  Dinner     4
# 52     Sun6165       34.81  5.20  Female     No   Sun  Dinner     4
# 85    Thur7972       34.83  5.17  Female     No  Thur   Lunch     4
# 102    Sat6240       44.30  2.50  Female    Yes   Sat  Dinner     3
# 197   Thur9313       43.11  5.00  Female    Yes  Thur   Lunch     4
# 219    Sat8863       30.14  3.09  Female    Yes   Sat  Dinner     4
# 238    Sat9777       35.83  4.67  Female     No   Sat  Dinner     3
#
#      price_per_person      Payer Name     CC Number
# 11               8.82    Diane Macias  4.577820e+15
# 52               8.70    Emily Daniel  4.291280e+15
# 85               8.71     Shawna Cook  6.011790e+15
# 102             14.77   Heather Cohen  3.797710e+14
# 197             10.78     Brooke Soto  5.544900e+15
# 219              7.54    Shelby House  5.020970e+11
# 238             11.94  Kimberly Crane  6.761840e+11

# %%
df_new = df[(df['total_bill'] > 30) & (df['tip'] > 5)]
df_new
# Out:
#     Payment ID  total_bill    tip  gender smoker   day    time  size  \
# 23      Sat239       39.42   7.58    Male     No   Sat  Dinner     4
# 44     Sun2274       30.40   5.60    Male     No   Sun  Dinner     4
# 47     Sun9677       32.40   6.00    Male     No   Sun  Dinner     4
# 52     Sun6165       34.81   5.20  Female     No   Sun  Dinner     4
# 59     Sat8139       48.27   6.73    Male     No   Sat  Dinner     4
# 85    Thur7972       34.83   5.17  Female     No  Thur   Lunch     4
# 141   Thur1025       34.30   6.70    Male     No  Thur   Lunch     6
# 170    Sat1954       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212    Sat4590       48.33   9.00    Male     No   Sat  Dinner     4
#
#      price_per_person       Payer Name     CC Number
# 23               9.86   Lance Peterson  3.542580e+15
# 44               7.60      Todd Cooper  5.038470e+11
# 47               8.10     James Barnes  3.552000e+15
# 52               8.70     Emily Daniel  4.291280e+15
# ...

# %%
# Conditional isin operator
options = ['Sat', 'Sun']            
df['day'].isin(options)                # isin function to check multiple conditions in DataFrame and It return the True/False
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 239     True
# 240     True
# 241     True
# 242     True
# 243    False
# Name: day, Length: 244, dtype: bool

# %%
df[df['day'].isin(['Sat','Sun'])]
# Out:
#     Payment ID  total_bill   tip  gender smoker  day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
# ..         ...         ...   ...     ...    ...  ...     ...   ...
# 238    Sat9777       35.83  4.67  Female     No  Sat  Dinner     3
# 239    Sat2657       29.03  5.92    Male     No  Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No  Sat  Dinner     2
#
#      price_per_person          Payer Name     CC Number
# 0                8.49  Christy Cunningham  3.560330e+15
# ...

# %%
# Sort Value
df.sort_values('tip')
# Out:
#     Payment ID  total_bill    tip  gender smoker   day    time  size  \
# 67     Sat3455        3.07   1.00  Female    Yes   Sat  Dinner     1
# 236    Sat5032       12.60   1.00    Male    Yes   Sat  Dinner     2
# 92     Fri3780        5.75   1.00  Female    Yes   Fri  Dinner     2
# 111    Sat4801        7.25   1.00  Female     No   Sat  Dinner     1
# 0      Sun2959       16.99   1.01  Female     No   Sun  Dinner     2
# ..         ...         ...    ...     ...    ...   ...     ...   ...
# 141   Thur1025       34.30   6.70    Male     No  Thur   Lunch     6
# 59     Sat8139       48.27   6.73    Male     No   Sat  Dinner     4
# 23      Sat239       39.42   7.58    Male     No   Sat  Dinner     4
# 212    Sat4590       48.33   9.00    Male     No   Sat  Dinner     4
# 170    Sat1954       50.81  10.00    Male    Yes   Sat  Dinner     3
#
#      price_per_person          Payer Name     CC Number
# 67               3.07       Tiffany Brock  4.359490e+15
# ...

# %%
# correlation
df[['total_bill', 'tip']].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
# idxmin and idxmin
print(df['total_bill'].max())
print(df['total_bill'].idxmax())
print(df['total_bill'].idxmin())
# Out:
# 50.81
# 170
# 67

# %%
print(df.iloc[67])
df.iloc[170]
# Out:
# Payment ID                     Sat3455
# total_bill                        3.07
# tip                                1.0
# gender                          Female
# smoker                             Yes
# day                                Sat
# time                            Dinner
# size                                 1
# price_per_person                  3.07
# Payer Name               Tiffany Brock
# CC Number           4359490000000000.0
# Name: 67, dtype: object
# Payment ID                     Sat1954
# total_bill                       50.81
# tip                               10.0
# gender                            Male
# smoker                             Yes
# day                                Sat
# time                            Dinner
# size                                 3
# price_per_person                 16.94
# Payer Name               Gregory Clark
# CC Number           5473850000000000.0
# Name: 170, dtype: object

# %%
# value_counts - get count on categorical columns
print(df['smoker'].value_counts())                # Smokers and Non-smokers
print(df['gender'].value_counts())                # Males and Females
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64
# gender
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
# unique
print(df['size'].unique())               # All the unique values as an array
print(df['size'].nunique())              # Number of unique values (i.e. count of the above array
print(df['time'].unique())               # for a char column
# Out:
# [2 3 4 1 6 5]
# 6
# ['Dinner' 'Lunch']

# %%
# between: options for inclusive are both, left, right, neither
df['total_bill'].between(10,20,inclusive='both')         # True/False
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242     True
# 243     True
# Name: total_bill, Length: 244, dtype: bool

# %%
df[df['total_bill'].between(10,20,inclusive='both')]    # Actual data
# Out:
#     Payment ID  total_bill   tip  gender smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 8      Sun6820       15.04  1.96    Male     No   Sun  Dinner     2
# 9      Sun3775       14.78  3.23    Male     No   Sun  Dinner     2
# 10     Sun2546       10.27  1.71    Male     No   Sun  Dinner     2
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 234    Sat7220       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235    Sat4615       10.07  1.25    Male     No   Sat  Dinner     2
# 236    Sat5032       12.60  1.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name     CC Number
# 0                8.49  Christy Cunningham  3.560330e+15
# ...

# %%
# Sample Data, randomly selected 
df.sample(5)          # 5 rows
# Out:
#     Payment ID  total_bill   tip  gender smoker   day    time  size  \
# 60     Sat2353       20.29  3.21    Male    Yes   Sat  Dinner     2
# 77    Thur4924       27.20  4.00    Male     No  Thur   Lunch     4
# 135   Thur6600        8.51  1.25  Female     No  Thur   Lunch     2
# 128   Thur8551       11.38  2.00  Female     No  Thur   Lunch     2
# 216    Sat7320       28.15  3.00    Male    Yes   Sat  Dinner     5
#
#      price_per_person         Payer Name     CC Number
# 60              10.14     Anthony Mclean  3.476140e+14
# 77               6.80         John Davis  3.034480e+13
# 135              4.26     Rebecca Harris  4.320270e+15
# 128              5.69  Christine Perkins  3.548390e+15
# 216              5.63  Shawn Barnett PhD  4.590980e+12

# %%
df.sample(frac=0.1)     # 10% of rows
# Out:
#     Payment ID  total_bill   tip  gender smoker   day    time  size  \
# 27      Sat394       12.69  2.00    Male     No   Sat  Dinner     2
# 98      Fri144       21.01  3.00    Male    Yes   Fri  Dinner     2
# 93     Fri6963       16.32  4.30  Female    Yes   Fri  Dinner     2
# 76     Sat9908       17.92  3.08    Male    Yes   Sat  Dinner     2
# 213    Sat1374       13.27  2.50  Female    Yes   Sat  Dinner     2
# 91     Fri5700       22.49  3.50    Male     No   Fri  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
# 225    Fri6665       16.27  2.50  Female    Yes   Fri   Lunch     2
# 160     Sun245       21.50  3.50    Male     No   Sun  Dinner     4
# 174    Sun7621       16.82  4.00    Male    Yes   Sun  Dinner     2
# 173    Sun9335       31.85  3.18    Male    Yes   Sun  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 227    Sat4319       20.45  3.00    Male     No   Sat  Dinner     4
# ...

# %%
# nlargest and nsamllest
df.nlargest(10, 'tip')         # n Largest tips
# Out:
#     Payment ID  total_bill    tip  gender smoker   day    time  size  \
# 170    Sat1954       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212    Sat4590       48.33   9.00    Male     No   Sat  Dinner     4
# 23      Sat239       39.42   7.58    Male     No   Sat  Dinner     4
# 59     Sat8139       48.27   6.73    Male     No   Sat  Dinner     4
# 141   Thur1025       34.30   6.70    Male     No  Thur   Lunch     6
# 183    Sun6059       23.17   6.50    Male    Yes   Sun  Dinner     4
# 214    Sat3374       28.17   6.50  Female    Yes   Sat  Dinner     3
# 47     Sun9677       32.40   6.00    Male     No   Sun  Dinner     4
# 239    Sat2657       29.03   5.92    Male     No   Sat  Dinner     3
# 88    Thur9003       24.71   5.85    Male     No  Thur   Lunch     2
#
#      price_per_person         Payer Name     CC Number
# 170             16.94      Gregory Clark  5.473850e+15
# 212             12.08    Alex Williamson  6.762190e+11
# ...

# %%
df.nsmallest(10,'tip')     # N smallest tips
# Out:
#     Payment ID  total_bill   tip  gender smoker   day    time  size  \
# 67     Sat3455        3.07  1.00  Female    Yes   Sat  Dinner     1
# 92     Fri3780        5.75  1.00  Female    Yes   Fri  Dinner     2
# 111    Sat4801        7.25  1.00  Female     No   Sat  Dinner     1
# 236    Sat5032       12.60  1.00    Male    Yes   Sat  Dinner     2
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 215    Sat6983       12.90  1.10  Female    Yes   Sat  Dinner     2
# 237    Sat2929       32.83  1.17    Male    Yes   Sat  Dinner     2
# 75     Sat5056       10.51  1.25    Male     No   Sat  Dinner     2
# 135   Thur6600        8.51  1.25  Female     No  Thur   Lunch     2
# 235    Sat4615       10.07  1.25    Male     No   Sat  Dinner     2
#
#      price_per_person          Payer Name     CC Number
# 67               3.07       Tiffany Brock  4.359490e+15
# 92               2.88        Leah Ramirez  3.508910e+15
# ...

# %% [markdown]
# groupby functionality:
# 1. Splitting: The data is first split into groups based the criteria provided
# 2. Applying: A function (or multiple functions) is applied to each group independently
# 3. Combining: The results of the function applications are then combined into a new DataFrame

# %%
# 1. Splitting
df_grouped =df.groupby('gender')
# Note that the output will not have any visible impact, except for
# a mention of grouping
print(df_grouped)

# %%
# 2. Applying
# Calculate the mean tip for each gender
mean_tip_by_gender = df_grouped['tip'].mean()
mean_tip_by_gender
# Out:
# gender
# Female    2.833448
# Male      3.089618
# Name: tip, dtype: float64

# %%
df_grouped['tip'].min()
# Out:
# gender  day
# Female  Fri     1.00
#         Sat     1.00
#         Sun     1.01
#         Thur    1.25
# Male    Fri     1.50
#         Sat     1.00
#         Sun     1.32
#         Thur    1.44
# Name: tip, dtype: float64

# %%
df_grouped['tip'].max()
# Out:
# gender  day
# Female  Fri      4.30
#         Sat      6.50
#         Sun      5.20
#         Thur     5.17
# Male    Fri      4.73
#         Sat     10.00
#         Sun      6.50
#         Thur     6.70
# Name: tip, dtype: float64

# %%
df_grouped['tip'].std()
# Out:
# gender  day
# Female  Fri     0.938862
#         Sat     1.234480
#         Sun     1.136775
#         Thur    1.109286
# Male    Fri     1.136428
#         Sat     1.791360
#         Sun     1.271172
#         Thur    1.353734
# Name: tip, dtype: float64

# %%
df_grouped['tip'].var()
# Out:
# gender  day
# Female  Fri     0.881461
#         Sat     1.523941
#         Sun     1.292257
#         Thur    1.230516
# Male    Fri     1.291468
#         Sat     3.208969
#         Sun     1.615877
#         Thur    1.832596
# Name: tip, dtype: float64

# %%
df_grouped['tip'].count()
# Out:
# gender  day
# Female  Fri      9
#         Sat     28
#         Sun     18
#         Thur    32
# Male    Fri     10
#         Sat     59
#         Sun     58
#         Thur    30
# Name: tip, dtype: int64

# %%
df_grouped['tip'].sum()
# Out:
# gender  day
# Female  Fri      25.03
#         Sat      78.45
#         Sun      60.61
#         Thur     82.42
# Male    Fri      26.93
#         Sat     181.95
#         Sun     186.78
#         Thur     89.41
# Name: tip, dtype: float64

# %%
# Creating groups on multiple columns
df_grouped = df.groupby(['gender','day'])
df_grouped['tip'].mean()
# Out:
# gender  day
# Female  Fri     2.781111
#         Sat     2.801786
#         Sun     3.367222
#         Thur    2.575625
# Male    Fri     2.693000
#         Sat     3.083898
#         Sun     3.220345
#         Thur    2.980333
# Name: tip, dtype: float64

# %% [markdown]
# --agg function--
# 1. Apply nmultiple aggregation functions to different columns when grouping data

# %%
# Calculate both the mean and sum of the 'tip' column for combination of 'gender' and 'day'
# Group the Dataframe by both 'gender' and 'day' and calculate the mean and sum of 'tip' each combination
df_grouped = df.groupby(['gender','day']).agg({'tip':['mean','sum']}).reset_index()
df_grouped
# Out:
#    gender   day       tip
#                      mean     sum
# 0  Female   Fri  2.781111   25.03
# 1  Female   Sat  2.801786   78.45
# 2  Female   Sun  3.367222   60.61
# 3  Female  Thur  2.575625   82.42
# 4    Male   Fri  2.693000   26.93
# 5    Male   Sat  3.083898  181.95
# 6    Male   Sun  3.220345  186.78
# 7    Male  Thur  2.980333   89.41

# %%
# Rename the columns for clarity
df_grouped.columns = ['gender', 'day', 'mean_tip', 'total_tip']
df_grouped
# Out:
#    gender   day  mean_tip  total_tip
# 0  Female   Fri  2.781111      25.03
# 1  Female   Sat  2.801786      78.45
# 2  Female   Sun  3.367222      60.61
# 3  Female  Thur  2.575625      82.42
# 4    Male   Fri  2.693000      26.93
# 5    Male   Sat  3.083898     181.95
# 6    Male   Sun  3.220345     186.78
# 7    Male  Thur  2.980333      89.41
